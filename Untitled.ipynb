# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#sch 10-6
x, y, z = np.loadtxt("datos.txt", skiprows=3, unpack=True)
plt.plot(x,y)
plt.show()

# %%
#---kerr 10-4 theta=0.1
x, y, z = np.loadtxt("kerr_0_1.txt", skiprows=3, unpack=True)
plt.xlabel("x - coordinate")
plt.ylabel("y - coordinate")
plt.plot(x,y,c="black")
plt.savefig("Kerr_01.pdf")
plt.show()

# %%
#---kerr 10-4 theta=pi/4
x, y, z = np.loadtxt("kerr_pi4.txt", skiprows=3, unpack=True)
plt.plot(x,y,c="black")
plt.xlabel("x - coordinate")
plt.ylabel("y - coordinate")
plt.savefig("Kerr_pi4.pdf")
plt.show()

# %%
#---kerr 10-4 theta=pi/2
x, y, z = np.loadtxt("kerr_pi2.txt", skiprows=3, unpack=True)
plt.plot(x,y)
plt.show()

# %%
#---kerr 10-4 theta=pi/3
x, y, z = np.loadtxt("kerr_pi3.txt", skiprows=3, unpack=True)
plt.plot(x,y)
plt.show()

# %%
#---kerr 10-4 theta=pi/6
x, y, z = np.loadtxt("kerr_pi6.txt", skiprows=3, unpack=True)
plt.plot(x,y)
plt.show()

# %%
#---kerr 10-4 theta=2pi
x, y, z = np.loadtxt("kerr_2pi.txt", skiprows=3, unpack=True)
plt.plot(x,y)
plt.show()

# %%
#---kerr 10-4 theta=3pi2
x, y, z = np.loadtxt("kerr_3pi2.txt", skiprows=3, unpack=True)
plt.plot(x,y)
plt.show()

# %%
#---kerr 10-4 theta=pi
x, y, z = np.loadtxt("kerr_pi.txt", skiprows=3, unpack=True)
plt.plot(x,y,c="black")
plt.xlabel("x - coordinate")
plt.ylabel("y - coordinate")
plt.savefig("Kerr_pi.pdf")
plt.show()
